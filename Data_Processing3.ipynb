# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
np.array([1,2,3])+np.array([2,3,4])
# Out:
# array([3, 5, 7])

# %%
data=pd.Series(np.arange(1,6))

# %%
data
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
stockmarket_data=pd.Series(np.random.randn(1000))

# %%
stockmarket_cumulative=stockmarket_data.cumsum()

# %%
stockmarket_cumulative.plot()

# %%
stock_prices=pd.DataFrame(np.random.rand(100,3))

# %%
stock_prices
# Out:
#            0         1         2
# 0   0.374374  0.400758  0.512697
# 1   0.239401  0.860014  0.734741
# 2   0.140957  0.409728  0.862192
# 3   0.577635  0.712904  0.266299
# 4   0.852889  0.801539  0.041336
# ..       ...       ...       ...
# 95  0.272245  0.865793  0.127881
# 96  0.793001  0.163888  0.282137
# 97  0.072090  0.729797  0.560898
# 98  0.913960  0.405976  0.614593
# 99  0.070515  0.248074  0.196286
#
# [100 rows x 3 columns]

# %%
stock_prices.columns=['India','Pakisthan','Bhutan']

# %%
stock_prices
# Out:
#        India  Pakisthan    Bhutan
# 0   0.374374   0.400758  0.512697
# 1   0.239401   0.860014  0.734741
# 2   0.140957   0.409728  0.862192
# 3   0.577635   0.712904  0.266299
# 4   0.852889   0.801539  0.041336
# ..       ...        ...       ...
# 95  0.272245   0.865793  0.127881
# 96  0.793001   0.163888  0.282137
# 97  0.072090   0.729797  0.560898
# 98  0.913960   0.405976  0.614593
# 99  0.070515   0.248074  0.196286
#
# [100 rows x 3 columns]

# %%
stock_prices.index=pd.date_range('1/1/2021',periods=100)

# %%
stock_prices
# Out:
#                India  Pakisthan    Bhutan
# 2021-01-01  0.374374   0.400758  0.512697
# 2021-01-02  0.239401   0.860014  0.734741
# 2021-01-03  0.140957   0.409728  0.862192
# 2021-01-04  0.577635   0.712904  0.266299
# 2021-01-05  0.852889   0.801539  0.041336
# ...              ...        ...       ...
# 2021-04-06  0.272245   0.865793  0.127881
# 2021-04-07  0.793001   0.163888  0.282137
# 2021-04-08  0.072090   0.729797  0.560898
# 2021-04-09  0.913960   0.405976  0.614593
# 2021-04-10  0.070515   0.248074  0.196286
#
# [100 rows x 3 columns]

# %%
stock_prices.to_csv('stock.csv')

# %%
stock_prices_cumulative=stock_prices.cumsum()

# %%
stock_prices_cumulative.plot()

# %%
# !wget https://raw.githubusercontent.com/ckrihub/bridge-sessions/main/ToyotaCorolla.csv
# Out:
# --2022-09-13 15:32:26--  https://raw.githubusercontent.com/ckrihub/bridge-sessions/main/ToyotaCorolla.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60530 (59K) [text/plain]
# Saving to: ‘ToyotaCorolla.csv.1’
#
# ToyotaCorolla.csv.1 100%[===================>]  59.11K  --.-KB/s    in 0.02s
#
# 2022-09-13 15:32:26 (2.60 MB/s) - ‘ToyotaCorolla.csv.1’ saved [60530/60530]

# %%
car_data=pd.read_csv('ToyotaCorolla.csv')
#we are opening in reading mode

# %%
car_data.tail()
# Out:
#       Price  Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 1431   7500   69  20544   Petrol   86         1          0  1300      3
# 1432  10845   72  19000   Petrol   86         0          0  1300      3
# 1433   8500   71  17016   Petrol   86         0          0  1300      3
# 1434   7250   70  16916   Petrol   86         1          0  1300      3
# 1435   6950   76      1   Petrol  110         0          0  1600      5
#
#       Weight
# 1431    1025
# 1432    1015
# 1433    1015
# 1434    1015
# 1435    1114

# %%
car_data.describe()
# Out:
#               Price          Age             KM           HP     MetColor  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.674791
# std     3626.964585    18.599988   37506.448872    14.981080     0.468616
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     1.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     1.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#          Automatic           CC        Doors      Weight
# count  1436.000000  1436.000000  1436.000000  1436.00000
# mean      0.055710  1566.827994     4.033426  1072.45961
# std       0.229441   187.182436     0.952677    52.64112
# min       0.000000  1300.000000     2.000000  1000.00000
# ...

# %%
car_data.ndim
# Out:
# 2

# %%
car_data.count()
# Out:
# Price        1436
# Age          1436
# KM           1436
# FuelType     1436
# HP           1436
# MetColor     1436
# Automatic    1436
# CC           1436
# Doors        1436
# Weight       1436
# dtype: int64

# %%
car_data.drop_duplicates()
# Out:
#       Price  Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0     13500   23  46986   Diesel   90         1          0  2000      3
# 1     13750   23  72937   Diesel   90         1          0  2000      3
# 2     13950   24  41711   Diesel   90         1          0  2000      3
# 3     14950   26  48000   Diesel   90         0          0  2000      3
# 4     13750   30  38500   Diesel   90         0          0  2000      3
# ...     ...  ...    ...      ...  ...       ...        ...   ...    ...
# 1431   7500   69  20544   Petrol   86         1          0  1300      3
# 1432  10845   72  19000   Petrol   86         0          0  1300      3
# 1433   8500   71  17016   Petrol   86         0          0  1300      3
# 1434   7250   70  16916   Petrol   86         1          0  1300      3
# 1435   6950   76      1   Petrol  110         0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...      ...
# ...

# %%
car_data.drop_duplicates(inplace=True)
#Here we are return the duplicate values

# %%
plt.scatter(car_data['Age'],car_data['Price'],)

# %%
plt.hist
# Out:
# <function matplotlib.pyplot.hist(x, bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, *, data=None, **kwargs)>

# %%
sns.regplot(x=car_data['Price'],y=car_data['Age'])

# %%
sns.regplot(x=car_data['Price'],y=car_data['Age'])
#This method is used to plot data and a linear regression model fit.

# %%
sns.lmplot(x='Price',y='Age',data=car_data, hue='FuelType')
#lmplot() method is used to draw a scatter plot onto a FacetGrid. Parameters

# %%
sns.pairplot(car_data,hue='FuelType')
